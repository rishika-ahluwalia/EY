# %%
import pandas as pd

# %%
filepath = "Census_states.xlsx"
df = pd.read_excel(filepath)
df.head()
# Out:
#   Unnamed: 0          State  Population  Increase  Area(Km2)  Density  \
# 0          -          India  1210854977    0.1764    3287240      382
# 1          1  Uttar Pradesh   199812341    0.2023     240928      829
# 2          2    Maharashtra   112374333    0.1599     307713      365
# 3          3          Bihar   104099452    0.2542      94163     1106
# 4          4    West Bengal    91276115    0.1384      88752     1028
#
#    Total Beds - Private + Public
# 0                            NaN
# 1                        17103.0
# 2                         3203.0
# 3                         3034.0
# 4                         2263.0

# %%
df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
df
# Out:
#                           State  Population  Increase  Area(Km2)  Density  \
# 0                         India  1210854977    0.1764    3287240      382
# 1                 Uttar Pradesh   199812341    0.2023     240928      829
# 2                   Maharashtra   112374333    0.1599     307713      365
# 3                         Bihar   104099452    0.2542      94163     1106
# 4                   West Bengal    91276115    0.1384      88752     1028
# 5                Andhra Pradesh    84580777    0.1098     275045      308
# 6                Madhya Pradesh    72626809    0.2035     308252      236
# 7                    Tamil Nadu    72147030    0.1561     130060      555
# 8                     Rajasthan    68548437    0.2131     342239      200
# 9                     Karnataka    61095297    0.1560     191791      319
# 10                      Gujarat    60439692    0.1928     196244      308
# 11                       Orissa    41974218    0.1405     155707      270
# ...

# %%
df = df.drop(index = 0 , columns = ['Increase', 'Area(Km2)', 'Density'])

# %%
df['New Population'] = df['Population']*11.2/100 + df['Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %% [markdown]
# <h3>Taking R0 as 2.08</h3><p>Calculating the Vaccine Coverage using the Vaccine Efficacy</p>
# <p>Vc = (1-1/R0)</p>

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.55
V55 = V*R
V55
# Out:
# 0.9440559440559441

# %%
df['Vc for Ve as 55%'] = V55 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.6
V60 = V*R
V60
# Out:
# 0.8653846153846155

# %%
df['Vc for Ve as 60%'] = V60 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.65
V65 = V*R
V65
df['Vc for Ve as 65%'] = V65 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.7
V7 = V*R
V7
df['Vc for Ve as 70%'] = V7 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.75
V75 = V*R
V75
df['Vc for Ve as 75%'] = V75 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.8
V80 = V*R
V80
df['Vc for Ve as 80%'] = V80 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.85
V85 = V*R
V85
df['Vc for Ve as 85%'] = V85 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.9
V90 = V*R
V90
df['Vc for Ve as 90%'] = V90 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
R0 = 2.08
R = (R0-1)/R0
V = 1/0.95
V95 = V*R
V95
df['Vc for Ve as 95%'] = V95 * df['New Population']
df
# Out:
#                           State  Population  Total Beds - Private + Public  \
# 1                 Uttar Pradesh   199812341                        17103.0
# 2                   Maharashtra   112374333                         3203.0
# 3                         Bihar   104099452                         3034.0
# 4                   West Bengal    91276115                         2263.0
# 5                Andhra Pradesh    84580777                          928.0
# 6                Madhya Pradesh    72626809                          971.0
# 7                    Tamil Nadu    72147030                         2439.0
# 8                     Rajasthan    68548437                         5644.0
# 9                     Karnataka    61095297                        10684.0
# 10                      Gujarat    60439692                         1408.0
# 11                       Orissa    41974218                         2501.0
# ...

# %%
df.to_excel('efficacy.xlsx')

# %%
# Out:
# None
